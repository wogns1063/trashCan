# %%
# 밑으로 홈페이지를 내렷을 때 정보가 나오는 경우 selenium 사용
# !pip install selenium
from selenium import webdriver
import os
import time

#찾고자 하는 검색어를 url로 만들어 준다.
searchterm = 'takeout-Cup'
url = "https://www.google.com/search?q="+searchterm+"&sxsrf=ACYBGNTHN8_c2BkwWl-c_nJ78-X7jh9lHw:1569220968104&source=lnms&tbm=isch&sa=X&ved=0ahUKEwjC1ILTq-bkAhVSPnAKHbF-AiUQ_AUIEigB&biw=1366&bih=657"

#chrome webdriver 사용하여 브라우저를 실행
browser = webdriver.Chrome("./chromedriver.exe")
browser.get(url)

# 검색 결과를 늘리기 위하여 스크롤 다운
for _ in range(10):
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(5)

# 소스코드가 있는 경로에 '검색어' 폴더가 없으면 만들어준다.
# (이미지 저장 폴더를 위해)
if not os.path.exists(searchterm):
    os.mkdir(searchterm)

#현재 수집된 이미지 수를 나타내는 변수
succounter = 0
#class name 이 THL인 요소를 모두 가지고 온다.
img_list = browser.find_elements_by_class_name('THL2l')
for idx, x in enumerate(img_list):
    try: 
        save_path = os.path.join(searchterm, str(idx)+".png")
        #이미지 저장
        x.screenshot(save_path)
        succounter = succounter + 1
        
        ranning_test = "ranning: " +str(succounter)+"/" +str(len(img_list))
        print(ranning_test)
        
    except:
        print("can't get img")

print(succounter, "succesfully download")
# Out:
# Requirement already satisfied: selenium in c:\users\wogns\anaconda3\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in c:\users\wogns\anaconda3\lib\site-packages (from selenium) (1.24.2)
# can't get img
# can't get img
# ranning: 1/300
# ranning: 2/300
# ranning: 3/300
# ranning: 4/300
# ranning: 5/300
# ranning: 6/300
# ranning: 7/300
# ranning: 8/300
# ranning: 9/300
# ranning: 10/300
# ranning: 11/300
# ranning: 12/300
# ranning: 13/300
# ranning: 14/300
# ranning: 15/300
# ranning: 16/300
# ranning: 17/300
# ranning: 18/300
# ranning: 19/300
# ranning: 20/300
# ranning: 21/300
# ranning: 22/300
# ranning: 23/300
# ranning: 24/300
# ranning: 25/300
# ranning: 26/300
# ranning: 27/300
# ranning: 28/300
# ranning: 29/300
# ranning: 30/300
# ranning: 31/300
# ranning: 32/300
# ranning: 33/300
# ranning: 34/300
# ranning: 35/300
# ranning: 36/300
# ranning: 37/300
# ranning: 38/300
# ranning: 39/300
# ranning: 40/300
# ranning: 41/300
# ranning: 42/300
# ranning: 43/300
# ranning: 44/300
# ranning: 45/300
# ranning: 46/300
# ranning: 47/300
# ranning: 48/300
# ranning: 49/300
# ranning: 50/300
# ranning: 51/300
# ranning: 52/300
# ranning: 53/300
# ranning: 54/300
# ranning: 55/300
# ranning: 56/300
# ranning: 57/300
# ranning: 58/300
# ranning: 59/300
# ranning: 60/300
# ranning: 61/300
# ranning: 62/300
# ranning: 63/300
# ranning: 64/300
# ranning: 65/300
# ranning: 66/300
# ranning: 67/300
# ranning: 68/300
# ranning: 69/300
# ranning: 70/300
# ranning: 71/300
# ranning: 72/300
# ranning: 73/300
# ranning: 74/300
# ranning: 75/300
# ranning: 76/300
# ranning: 77/300
# ranning: 78/300
# ranning: 79/300
# ranning: 80/300
# ranning: 81/300
# ranning: 82/300
# ranning: 83/300
# ranning: 84/300
# ranning: 85/300
# ranning: 86/300
# ranning: 87/300
# ranning: 88/300
# ranning: 89/300
# ranning: 90/300
# ranning: 91/300
# ranning: 92/300
# ranning: 93/300
# ranning: 94/300
# ranning: 95/300
# ranning: 96/300
# ranning: 97/300
# ranning: 98/300
# ranning: 99/300
# ranning: 100/300
# ranning: 101/300
# ranning: 102/300
# ranning: 103/300
# ranning: 104/300
# ranning: 105/300
# ranning: 106/300
# ranning: 107/300
# ranning: 108/300
# ranning: 109/300
# ranning: 110/300
# ranning: 111/300
# ranning: 112/300
# ranning: 113/300
# ranning: 114/300
# ranning: 115/300
# ranning: 116/300
# ranning: 117/300
# ranning: 118/300
# ranning: 119/300
# ranning: 120/300
# ranning: 121/300
# ranning: 122/300
# ranning: 123/300
# ranning: 124/300
# ranning: 125/300
# ranning: 126/300
# ranning: 127/300
# ranning: 128/300
# ranning: 129/300
# ranning: 130/300
# ranning: 131/300
# ranning: 132/300
# ranning: 133/300
# ranning: 134/300
# ranning: 135/300
# ranning: 136/300
# ranning: 137/300
# ranning: 138/300
# ranning: 139/300
# ranning: 140/300
# ranning: 141/300
# ranning: 142/300
# ranning: 143/300
# ranning: 144/300
# ranning: 145/300
# ranning: 146/300
# ranning: 147/300
# ranning: 148/300
# ranning: 149/300
# ranning: 150/300
# ranning: 151/300
# ranning: 152/300
# ranning: 153/300
# ranning: 154/300
# ranning: 155/300
# ranning: 156/300
# ranning: 157/300
# ranning: 158/300
# ranning: 159/300
# ranning: 160/300
# ranning: 161/300
# ranning: 162/300
# ranning: 163/300
# ranning: 164/300
# ranning: 165/300
# ranning: 166/300
# ranning: 167/300
# ranning: 168/300
# ranning: 169/300
# ranning: 170/300
# ranning: 171/300
# ranning: 172/300
# ranning: 173/300
# ranning: 174/300
# ranning: 175/300
# ranning: 176/300
# ranning: 177/300
# ranning: 178/300
# ranning: 179/300
# ranning: 180/300
# ranning: 181/300
# ranning: 182/300
# ranning: 183/300
# ranning: 184/300
# ranning: 185/300
# ranning: 186/300
# ranning: 187/300
# ranning: 188/300
# ranning: 189/300
# ranning: 190/300
# ranning: 191/300
# ranning: 192/300
# ranning: 193/300
# ranning: 194/300
# ranning: 195/300
# ranning: 196/300
# ranning: 197/300
# ranning: 198/300
# ranning: 199/300
# ranning: 200/300
# ranning: 201/300
# ranning: 202/300
# ranning: 203/300
# ranning: 204/300
# ranning: 205/300
# ranning: 206/300
# ranning: 207/300
# ranning: 208/300
# ranning: 209/300
# ranning: 210/300
# ranning: 211/300
# ranning: 212/300
# ranning: 213/300
# ranning: 214/300
# ranning: 215/300
# ranning: 216/300
# ranning: 217/300
# ranning: 218/300
# ranning: 219/300
# ranning: 220/300
# ranning: 221/300
# ranning: 222/300
# ranning: 223/300
# ranning: 224/300
# ranning: 225/300
# ranning: 226/300
# ranning: 227/300
# ranning: 228/300
# ranning: 229/300
# ranning: 230/300
# ranning: 231/300
# ranning: 232/300
# ranning: 233/300
# ranning: 234/300
# ranning: 235/300
# ranning: 236/300
# ranning: 237/300
# ranning: 238/300
# ranning: 239/300
# ranning: 240/300
# ranning: 241/300
# ranning: 242/300
# ranning: 243/300
# ranning: 244/300
# ranning: 245/300
# ranning: 246/300
# ranning: 247/300
# ranning: 248/300
# ranning: 249/300
# ranning: 250/300
# ranning: 251/300
# ranning: 252/300
# ranning: 253/300
# ranning: 254/300
# ranning: 255/300
# ranning: 256/300
# ranning: 257/300
# ranning: 258/300
# ranning: 259/300
# ranning: 260/300
# ranning: 261/300
# ranning: 262/300
# ranning: 263/300
# ranning: 264/300
# ranning: 265/300
# ranning: 266/300
# ranning: 267/300
# ranning: 268/300
# ranning: 269/300
# ranning: 270/300
# ranning: 271/300
# ranning: 272/300
# ranning: 273/300
# ranning: 274/300
# ranning: 275/300
# ranning: 276/300
# ranning: 277/300
# ranning: 278/300
# ranning: 279/300
# ranning: 280/300
# ranning: 281/300
# ranning: 282/300
# ranning: 283/300
# ranning: 284/300
# ranning: 285/300
# ranning: 286/300
# ranning: 287/300
# ranning: 288/300
# ranning: 289/300
# ranning: 290/300
# ranning: 291/300
# ranning: 292/300
# ranning: 293/300
# ranning: 294/300
# ranning: 295/300
# ranning: 296/300
# ranning: 297/300
# ranning: 298/300
# 298 succesfully download
